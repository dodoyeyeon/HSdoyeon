# %%
import csv
f = open('정보 자료.csv')
data = csv.reader(f)

for row in data :
    print(row[0],float(row[1])+float(row[2])+float(row[3])+float(row[4])+float(row[5])+float(row[6])+float(row[7])+float(row[8])+float(row[9])+float(row[10]))
# Out:
# 서울 1129.0
# 부산 277.0
# 대구 407.0
# 인천 442.0
# 광주 310.0
# 대전 210.0
# 울산 93.0
# 세종 23.0
# 경기 2043.0
# 강원 430.0
# 충북 372.0
# 충남 385.0
# 전북 444.0
# 전남 575.0
# 경북 539.0
# 경남 411.0
# 제주 114.0

# %%
import matplotlib.pyplot as plt
plt.plot([1129,277,407,442,310,210,93,23,2043,430,372,385,444,575,539,411,114])
plt.xticks(range(17),['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주'])
plt.rc('font',family='Malgun Gothic')
plt.title('시군구별 복지시설 수')
plt.savefig('data0.png')
plt.show()
